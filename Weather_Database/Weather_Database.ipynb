# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime
import gmaps
import requests
from config import weather_api_key
from config import g_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_wx_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_wx_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | kaitangata
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | sinnamary
# Processing Record 5 of Set 1 | bengkulu
# Processing Record 6 of Set 1 | ayan
# Processing Record 7 of Set 1 | ilulissat
# Processing Record 8 of Set 1 | santa rosa
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | nanortalik
# Processing Record 12 of Set 1 | chuy
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 16 of Set 1 | tasiilaq
# Processing Record 17 of Set 1 | mar del plata
# Processing Record 18 of Set 1 | tuktoyaktuk
# Processing Record 19 of Set 1 | alanya
# Processing Record 20 of Set 1 | el tarra
# Processing Record 21 of Set 1 | lavrentiya
# Processing Record 22 of Set 1 | bredasdorp
# Processing Record 23 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | cidreira
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | songea
# Processing Record 31 of Set 1 | svetlogorsk
# Processing Record 32 of Set 1 | karkaralinsk
# City not found. Skipping...
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | tabou
# Processing Record 35 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 1 | paramirim
# Processing Record 37 of Set 1 | pimentel
# Processing Record 38 of Set 1 | russell
# Processing Record 39 of Set 1 | lorengau
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | airai
# Processing Record 43 of Set 1 | mahebourg
# Processing Record 44 of Set 1 | beloha
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | gondanglegi
# Processing Record 48 of Set 1 | sisimiut
# Processing Record 49 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 1 | leningradskiy
# Processing Record 1 of Set 2 | muros
# Processing Record 2 of Set 2 | derbent
# Processing Record 3 of Set 2 | castro
# Processing Record 4 of Set 2 | karratha
# Processing Record 5 of Set 2 | butaritari
# Processing Record 6 of Set 2 | chhuikhadan
# Processing Record 7 of Set 2 | hithadhoo
# Processing Record 8 of Set 2 | pevek
# Processing Record 9 of Set 2 | mwingi
# Processing Record 10 of Set 2 | olinda
# Processing Record 11 of Set 2 | comodoro rivadavia
# Processing Record 12 of Set 2 | esperance
# Processing Record 13 of Set 2 | east london
# Processing Record 14 of Set 2 | ribeira grande
# Processing Record 15 of Set 2 | mangrol
# Processing Record 16 of Set 2 | maumere
# Processing Record 17 of Set 2 | angatuba
# Processing Record 18 of Set 2 | busselton
# Processing Record 19 of Set 2 | cabo san lucas
# Processing Record 20 of Set 2 | geraldton
# Processing Record 21 of Set 2 | waipawa
# Processing Record 22 of Set 2 | ternate
# Processing Record 23 of Set 2 | tilichiki
# Processing Record 24 of Set 2 | hongjiang
# Processing Record 25 of Set 2 | amethi
# Processing Record 26 of Set 2 | saint-philippe
# Processing Record 27 of Set 2 | arraial do cabo
# Processing Record 28 of Set 2 | cutervo
# Processing Record 29 of Set 2 | ahipara
# Processing Record 30 of Set 2 | codrington
# Processing Record 31 of Set 2 | pousat
# City not found. Skipping...
# Processing Record 32 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 2 | albany
# Processing Record 34 of Set 2 | chokurdakh
# Processing Record 35 of Set 2 | atuona
# Processing Record 36 of Set 2 | marevo
# Processing Record 37 of Set 2 | thompson
# Processing Record 38 of Set 2 | namibe
# Processing Record 39 of Set 2 | ranfurly
# Processing Record 40 of Set 2 | shimoda
# Processing Record 41 of Set 2 | vaini
# Processing Record 42 of Set 2 | fairbanks
# Processing Record 43 of Set 2 | komsomolskiy
# Processing Record 44 of Set 2 | tura
# Processing Record 45 of Set 2 | khatanga
# Processing Record 46 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 47 of Set 2 | carnarvon
# Processing Record 48 of Set 2 | udachnyy
# Processing Record 49 of Set 2 | ngama
# Processing Record 50 of Set 2 | cherskiy
# Processing Record 1 of Set 3 | dingle
# Processing Record 2 of Set 3 | santa maria
# Processing Record 3 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 3 | los llanos de aridane
# Processing Record 5 of Set 3 | ayagoz
# Processing Record 6 of Set 3 | vila velha
# Processing Record 7 of Set 3 | naze
# Processing Record 8 of Set 3 | kodiak
# Processing Record 9 of Set 3 | severo-kurilsk
# Processing Record 10 of Set 3 | chekhov
# Processing Record 11 of Set 3 | saint george
# Processing Record 12 of Set 3 | taunggyi
# Processing Record 13 of Set 3 | torbay
# Processing Record 14 of Set 3 | sitka
# Processing Record 15 of Set 3 | avdon
# Processing Record 16 of Set 3 | port macquarie
# Processing Record 17 of Set 3 | vandoeuvre-les-nancy
# Processing Record 18 of Set 3 | inhambane
# Processing Record 19 of Set 3 | broome
# Processing Record 20 of Set 3 | lebu
# Processing Record 21 of Set 3 | verkhnyaya toyma
# Processing Record 22 of Set 3 | bambous virieux
# Processing Record 23 of Set 3 | ponta do sol
# Processing Record 24 of Set 3 | duldurga
# Processing Record 25 of Set 3 | san quintin
# Processing Record 26 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 3 | ganzhou
# Processing Record 28 of Set 3 | cabedelo
# Processing Record 29 of Set 3 | wawa
# Processing Record 30 of Set 3 | vardo
# Processing Record 31 of Set 3 | tuatapere
# Processing Record 32 of Set 3 | vila franca do campo
# Processing Record 33 of Set 3 | saskylakh
# Processing Record 34 of Set 3 | flinders
# Processing Record 35 of Set 3 | alashtar
# City not found. Skipping...
# Processing Record 36 of Set 3 | ngunguru
# Processing Record 37 of Set 3 | saldanha
# Processing Record 38 of Set 3 | lichinga
# Processing Record 39 of Set 3 | la macarena
# Processing Record 40 of Set 3 | bossangoa
# Processing Record 41 of Set 3 | acapulco
# Processing Record 42 of Set 3 | taoudenni
# Processing Record 43 of Set 3 | raghunathpur
# Processing Record 44 of Set 3 | alyangula
# Processing Record 45 of Set 3 | georgetown
# Processing Record 46 of Set 3 | livingston
# Processing Record 47 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 3 | rio rancho
# Processing Record 49 of Set 3 | santa fe
# Processing Record 50 of Set 3 | kahului
# Processing Record 1 of Set 4 | cap malheureux
# Processing Record 2 of Set 4 | ambilobe
# Processing Record 3 of Set 4 | buluang
# Processing Record 4 of Set 4 | candawaga
# City not found. Skipping...
# Processing Record 5 of Set 4 | tessalit
# Processing Record 6 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 4 | toma
# Processing Record 8 of Set 4 | bubaque
# Processing Record 9 of Set 4 | voh
# Processing Record 10 of Set 4 | tiksi
# Processing Record 11 of Set 4 | killybegs
# Processing Record 12 of Set 4 | natitingou
# Processing Record 13 of Set 4 | summerville
# Processing Record 14 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 15 of Set 4 | cam ranh
# Processing Record 16 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 4 | lompoc
# Processing Record 18 of Set 4 | kondinskoye
# Processing Record 19 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 4 | sampit
# Processing Record 21 of Set 4 | vysokogornyy
# Processing Record 22 of Set 4 | nikolskoye
# Processing Record 23 of Set 4 | bonavista
# Processing Record 24 of Set 4 | nemuro
# Processing Record 25 of Set 4 | naryan-mar
# Processing Record 26 of Set 4 | qaanaaq
# Processing Record 27 of Set 4 | biak
# Processing Record 28 of Set 4 | talnakh
# Processing Record 29 of Set 4 | guerrero negro
# Processing Record 30 of Set 4 | nakamura
# Processing Record 31 of Set 4 | high prairie
# Processing Record 32 of Set 4 | kawalu
# Processing Record 33 of Set 4 | port elizabeth
# Processing Record 34 of Set 4 | dhidhdhoo
# Processing Record 35 of Set 4 | along
# Processing Record 36 of Set 4 | pacatuba
# Processing Record 37 of Set 4 | ust-tsilma
# Processing Record 38 of Set 4 | katsuura
# Processing Record 39 of Set 4 | melo
# Processing Record 40 of Set 4 | badarpur
# Processing Record 41 of Set 4 | ostrovnoy
# Processing Record 42 of Set 4 | nurota
# Processing Record 43 of Set 4 | prince rupert
# Processing Record 44 of Set 4 | ronne
# Processing Record 45 of Set 4 | tevriz
# Processing Record 46 of Set 4 | clyde river
# Processing Record 47 of Set 4 | sofiysk
# City not found. Skipping...
# Processing Record 48 of Set 4 | tillabery
# City not found. Skipping...
# Processing Record 49 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 4 | viedma
# Processing Record 1 of Set 5 | hamilton
# Processing Record 2 of Set 5 | pisco
# Processing Record 3 of Set 5 | natal
# Processing Record 4 of Set 5 | touros
# Processing Record 5 of Set 5 | auki
# Processing Record 6 of Set 5 | hambantota
# Processing Record 7 of Set 5 | beringovskiy
# Processing Record 8 of Set 5 | san blas
# Processing Record 9 of Set 5 | aksu
# Processing Record 10 of Set 5 | port hedland
# Processing Record 11 of Set 5 | constitucion
# Processing Record 12 of Set 5 | gigant
# Processing Record 13 of Set 5 | itaituba
# Processing Record 14 of Set 5 | labuhan
# Processing Record 15 of Set 5 | maniitsoq
# Processing Record 16 of Set 5 | kapaa
# Processing Record 17 of Set 5 | bethel
# Processing Record 18 of Set 5 | alekseyevsk
# Processing Record 19 of Set 5 | buqayq
# City not found. Skipping...
# Processing Record 20 of Set 5 | vao
# Processing Record 21 of Set 5 | vakhrushevo
# Processing Record 22 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 5 | henties bay
# Processing Record 24 of Set 5 | akdepe
# Processing Record 25 of Set 5 | ancud
# Processing Record 26 of Set 5 | manuk mangkaw
# Processing Record 27 of Set 5 | letka
# Processing Record 28 of Set 5 | san policarpo
# Processing Record 29 of Set 5 | avera
# Processing Record 30 of Set 5 | assomada
# Processing Record 31 of Set 5 | manali
# Processing Record 32 of Set 5 | penzance
# Processing Record 33 of Set 5 | atar
# Processing Record 34 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 35 of Set 5 | wad madani
# Processing Record 36 of Set 5 | chunskiy
# Processing Record 37 of Set 5 | yicheng
# Processing Record 38 of Set 5 | swan hill
# Processing Record 39 of Set 5 | tarancon
# Processing Record 40 of Set 5 | muzaffarabad
# Processing Record 41 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 5 | provideniya
# Processing Record 43 of Set 5 | avarua
# Processing Record 44 of Set 5 | colares
# Processing Record 45 of Set 5 | san luis rio colorado
# Processing Record 46 of Set 5 | hammerfest
# Processing Record 47 of Set 5 | thinadhoo
# Processing Record 48 of Set 5 | port lincoln
# Processing Record 49 of Set 5 | toora-khem
# Processing Record 50 of Set 5 | ust-maya
# Processing Record 1 of Set 6 | sao joao da barra
# Processing Record 2 of Set 6 | palaikastron
# Processing Record 3 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 4 of Set 6 | isangel
# Processing Record 5 of Set 6 | ballina
# Processing Record 6 of Set 6 | padang
# Processing Record 7 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 6 | verkh-usugli
# Processing Record 9 of Set 6 | hualmay
# Processing Record 10 of Set 6 | tianpeng
# Processing Record 11 of Set 6 | lata
# Processing Record 12 of Set 6 | longyearbyen
# Processing Record 13 of Set 6 | teya
# Processing Record 14 of Set 6 | ardistan
# City not found. Skipping...
# Processing Record 15 of Set 6 | excelsior springs
# Processing Record 16 of Set 6 | perth
# Processing Record 17 of Set 6 | caravelas
# Processing Record 18 of Set 6 | broken hill
# Processing Record 19 of Set 6 | usinsk
# Processing Record 20 of Set 6 | durres
# Processing Record 21 of Set 6 | balassagyarmat
# Processing Record 22 of Set 6 | tunduru
# City not found. Skipping...
# Processing Record 23 of Set 6 | gat
# Processing Record 24 of Set 6 | urumqi
# Processing Record 25 of Set 6 | port hawkesbury
# Processing Record 26 of Set 6 | tautira
# Processing Record 27 of Set 6 | kloulklubed
# Processing Record 28 of Set 6 | alofi
# Processing Record 29 of Set 6 | takoradi
# Processing Record 30 of Set 6 | yeppoon
# Processing Record 31 of Set 6 | abha
# Processing Record 32 of Set 6 | asau
# Processing Record 33 of Set 6 | kununurra
# Processing Record 34 of Set 6 | merauke
# Processing Record 35 of Set 6 | bakhmach
# Processing Record 36 of Set 6 | necochea
# Processing Record 37 of Set 6 | yumen
# Processing Record 38 of Set 6 | saint-ambroise
# Processing Record 39 of Set 6 | salisbury
# Processing Record 40 of Set 6 | shenxian
# Processing Record 41 of Set 6 | novikovo
# Processing Record 42 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 43 of Set 6 | zhigansk
# Processing Record 44 of Set 6 | narsaq
# Processing Record 45 of Set 6 | salalah
# Processing Record 46 of Set 6 | afua
# Processing Record 47 of Set 6 | weston
# Processing Record 48 of Set 6 | chanika
# Processing Record 49 of Set 6 | nizwa
# Processing Record 50 of Set 6 | coquimbo
# Processing Record 1 of Set 7 | khao yoi
# Processing Record 2 of Set 7 | turukhansk
# Processing Record 3 of Set 7 | manokwari
# Processing Record 4 of Set 7 | mount isa
# Processing Record 5 of Set 7 | anzio
# Processing Record 6 of Set 7 | te anau
# Processing Record 7 of Set 7 | gelemso
# Processing Record 8 of Set 7 | upernavik
# Processing Record 9 of Set 7 | hohhot
# Processing Record 10 of Set 7 | coihueco
# Processing Record 11 of Set 7 | qaqortoq
# Processing Record 12 of Set 7 | novoagansk
# Processing Record 13 of Set 7 | hirado
# Processing Record 14 of Set 7 | cayenne
# Processing Record 15 of Set 7 | marhaura
# Processing Record 16 of Set 7 | roma
# Processing Record 17 of Set 7 | groton
# Processing Record 18 of Set 7 | praia da vitoria
# Processing Record 19 of Set 7 | sandwick
# Processing Record 20 of Set 7 | winnemucca
# Processing Record 21 of Set 7 | arklow
# Processing Record 22 of Set 7 | grindavik
# Processing Record 23 of Set 7 | lazaro cardenas
# Processing Record 24 of Set 7 | paamiut
# Processing Record 25 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 7 | kyshtovka
# Processing Record 27 of Set 7 | norman wells
# Processing Record 28 of Set 7 | banda aceh
# Processing Record 29 of Set 7 | cooma
# Processing Record 30 of Set 7 | humaita
# Processing Record 31 of Set 7 | sao jose da coroa grande
# Processing Record 32 of Set 7 | iquique
# Processing Record 33 of Set 7 | tucupita
# Processing Record 34 of Set 7 | bandarbeyla
# Processing Record 35 of Set 7 | ambulu
# Processing Record 36 of Set 7 | ulaanbaatar
# Processing Record 37 of Set 7 | sao filipe
# Processing Record 38 of Set 7 | bischwiller
# Processing Record 39 of Set 7 | gigmoto
# Processing Record 40 of Set 7 | chapais
# Processing Record 41 of Set 7 | dunedin
# Processing Record 42 of Set 7 | iracoubo
# Processing Record 43 of Set 7 | faanui
# Processing Record 44 of Set 7 | aquiraz
# Processing Record 45 of Set 7 | skibbereen
# Processing Record 46 of Set 7 | altay
# Processing Record 47 of Set 7 | san cristobal
# Processing Record 48 of Set 7 | berlevag
# Processing Record 49 of Set 7 | boras
# Processing Record 50 of Set 7 | kavieng
# Processing Record 1 of Set 8 | porbandar
# Processing Record 2 of Set 8 | port augusta
# Processing Record 3 of Set 8 | tabukiniberu
# City not found. Skipping...
# Processing Record 4 of Set 8 | lucea
# Processing Record 5 of Set 8 | pedasi
# Processing Record 6 of Set 8 | uchiza
# Processing Record 7 of Set 8 | igrim
# Processing Record 8 of Set 8 | pandaria
# Processing Record 9 of Set 8 | harper
# Processing Record 10 of Set 8 | sorland
# Processing Record 11 of Set 8 | vung tau
# Processing Record 12 of Set 8 | hervey bay
# Processing Record 13 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 14 of Set 8 | khowst
# Processing Record 15 of Set 8 | bocaiuva
# Processing Record 16 of Set 8 | sabha
# Processing Record 17 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 18 of Set 8 | lixourion
# Processing Record 19 of Set 8 | yermakovskoye
# Processing Record 20 of Set 8 | nipawin
# Processing Record 21 of Set 8 | rosarito
# Processing Record 22 of Set 8 | cortez
# Processing Record 23 of Set 8 | wanaka
# Processing Record 24 of Set 8 | saint-augustin
# Processing Record 25 of Set 8 | marsh harbour
# Processing Record 26 of Set 8 | bowen
# Processing Record 27 of Set 8 | bodrum
# Processing Record 28 of Set 8 | cotonou
# Processing Record 29 of Set 8 | lupiro
# Processing Record 30 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 8 | maribo
# Processing Record 33 of Set 8 | camacupa
# Processing Record 34 of Set 8 | hasaki
# Processing Record 35 of Set 8 | kalispell
# Processing Record 36 of Set 8 | quatre cocos
# Processing Record 37 of Set 8 | tongren
# Processing Record 38 of Set 8 | mount gambier
# Processing Record 39 of Set 8 | yeletskiy
# City not found. Skipping...
# Processing Record 40 of Set 8 | benghazi
# Processing Record 41 of Set 8 | ngorongoro
# Processing Record 42 of Set 8 | kastamonu
# Processing Record 43 of Set 8 | ankpa
# Processing Record 44 of Set 8 | heihe
# Processing Record 45 of Set 8 | dukstas
# Processing Record 46 of Set 8 | marzuq
# Processing Record 47 of Set 8 | merrill
# Processing Record 48 of Set 8 | kyabe
# Processing Record 49 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 8 | mareeba
# Processing Record 1 of Set 9 | kruisfontein
# Processing Record 2 of Set 9 | whitehorse
# Processing Record 3 of Set 9 | monzon
# Processing Record 4 of Set 9 | bam
# Processing Record 5 of Set 9 | nishihara
# Processing Record 6 of Set 9 | progreso
# Processing Record 7 of Set 9 | goderich
# Processing Record 8 of Set 9 | palu
# Processing Record 9 of Set 9 | kuandian
# Processing Record 10 of Set 9 | dawei
# Processing Record 11 of Set 9 | dikson
# Processing Record 12 of Set 9 | funadhoo
# Processing Record 13 of Set 9 | toccoa
# Processing Record 14 of Set 9 | sabang
# Processing Record 15 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 16 of Set 9 | lang son
# Processing Record 17 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 18 of Set 9 | shihezi
# Processing Record 19 of Set 9 | nevelsk
# Processing Record 20 of Set 9 | havre-saint-pierre
# Processing Record 21 of Set 9 | hella
# Processing Record 22 of Set 9 | daru
# Processing Record 23 of Set 9 | kamenka
# Processing Record 24 of Set 9 | vreed en hoop
# City not found. Skipping...
# Processing Record 25 of Set 9 | sola
# Processing Record 26 of Set 9 | redlands
# Processing Record 27 of Set 9 | innisfail
# Processing Record 28 of Set 9 | souillac
# Processing Record 29 of Set 9 | puerto del rosario
# Processing Record 30 of Set 9 | kalmunai
# Processing Record 31 of Set 9 | okhotsk
# Processing Record 32 of Set 9 | stargard szczecinski
# Processing Record 33 of Set 9 | victoria
# Processing Record 34 of Set 9 | college
# Processing Record 35 of Set 9 | vanimo
# Processing Record 36 of Set 9 | vila
# Processing Record 37 of Set 9 | palmer
# Processing Record 38 of Set 9 | messina
# Processing Record 39 of Set 9 | otjiwarongo
# Processing Record 40 of Set 9 | klaksvik
# Processing Record 41 of Set 9 | sterling
# Processing Record 42 of Set 9 | ushtobe
# Processing Record 43 of Set 9 | ilhabela
# Processing Record 44 of Set 9 | tuy hoa
# Processing Record 45 of Set 9 | navapur
# City not found. Skipping...
# Processing Record 46 of Set 9 | brigantine
# Processing Record 47 of Set 9 | kolimvari
# City not found. Skipping...
# Processing Record 48 of Set 9 | muzambinho
# Processing Record 49 of Set 9 | boatlaname
# City not found. Skipping...
# Processing Record 50 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 1 of Set 10 | aasiaat
# Processing Record 2 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 3 of Set 10 | caraballeda
# Processing Record 4 of Set 10 | dubreka
# Processing Record 5 of Set 10 | meulaboh
# Processing Record 6 of Set 10 | invermere
# Processing Record 7 of Set 10 | ondjiva
# Processing Record 8 of Set 10 | iqaluit
# Processing Record 9 of Set 10 | san patricio
# Processing Record 10 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 11 of Set 10 | maragogi
# Processing Record 12 of Set 10 | saint-pierre
# Processing Record 13 of Set 10 | antalaha
# Processing Record 14 of Set 10 | porto walter
# Processing Record 15 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 10 | belmonte
# Processing Record 17 of Set 10 | oranjestad
# Processing Record 18 of Set 10 | ambon
# Processing Record 19 of Set 10 | fortuna
# Processing Record 20 of Set 10 | pachino
# Processing Record 21 of Set 10 | lodja
# Processing Record 22 of Set 10 | tocopilla
# Processing Record 23 of Set 10 | taltal
# Processing Record 24 of Set 10 | honningsvag
# Processing Record 25 of Set 10 | itarema
# Processing Record 26 of Set 10 | saint paul
# Processing Record 27 of Set 10 | shingu
# Processing Record 28 of Set 10 | kurilsk
# Processing Record 29 of Set 10 | kaputa
# Processing Record 30 of Set 10 | autun
# Processing Record 31 of Set 10 | angol
# Processing Record 32 of Set 10 | guaymas
# Processing Record 33 of Set 10 | bintulu
# Processing Record 34 of Set 10 | patterson
# Processing Record 35 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 10 | choma
# Processing Record 37 of Set 10 | umm kaddadah
# Processing Record 38 of Set 10 | riyadh
# Processing Record 39 of Set 10 | khani
# Processing Record 40 of Set 10 | sistranda
# Processing Record 41 of Set 10 | sur
# Processing Record 42 of Set 10 | edson
# Processing Record 43 of Set 10 | bhatkal
# Processing Record 44 of Set 10 | traverse city
# Processing Record 45 of Set 10 | alice springs
# Processing Record 46 of Set 10 | carinhanha
# Processing Record 47 of Set 10 | sechura
# Processing Record 48 of Set 10 | epe
# Processing Record 49 of Set 10 | azangaro
# Processing Record 50 of Set 10 | vanavara
# Processing Record 1 of Set 11 | margate
# Processing Record 2 of Set 11 | corsicana
# Processing Record 3 of Set 11 | kandrian
# Processing Record 4 of Set 11 | mayor pablo lagerenza
# Processing Record 5 of Set 11 | tokmak
# Processing Record 6 of Set 11 | luanda
# Processing Record 7 of Set 11 | srednekolymsk
# Processing Record 8 of Set 11 | adrar
# Processing Record 9 of Set 11 | dalbandin
# Processing Record 10 of Set 11 | valle de allende
# Processing Record 11 of Set 11 | wajima
# Processing Record 12 of Set 11 | jurm
# Processing Record 13 of Set 11 | tuysarkan
# City not found. Skipping...
# Processing Record 14 of Set 11 | florianopolis
# Processing Record 15 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 16 of Set 11 | haines junction
# Processing Record 17 of Set 11 | channel-port aux basques
# Processing Record 18 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 11 | grand gaube
# Processing Record 20 of Set 11 | chara
# Processing Record 21 of Set 11 | balagansk
# Processing Record 22 of Set 11 | mantua
# Processing Record 23 of Set 11 | westport
# Processing Record 24 of Set 11 | aojiang
# Processing Record 25 of Set 11 | suntar
# Processing Record 26 of Set 11 | chabahar
# Processing Record 27 of Set 11 | abu kamal
# Processing Record 28 of Set 11 | fengxian
# Processing Record 29 of Set 11 | homer
# Processing Record 30 of Set 11 | hobyo
# Processing Record 31 of Set 11 | port hardy
# Processing Record 32 of Set 11 | chirongui
# Processing Record 33 of Set 11 | isla vista
# Processing Record 34 of Set 11 | sakakah
# Processing Record 35 of Set 11 | maamba
# Processing Record 36 of Set 11 | baghdad
# Processing Record 37 of Set 11 | koson
# Processing Record 38 of Set 11 | rognan
# Processing Record 39 of Set 11 | pacific grove
# Processing Record 40 of Set 11 | camana
# Processing Record 41 of Set 11 | cabiraoan
# Processing Record 42 of Set 11 | formosa
# Processing Record 43 of Set 11 | revelstoke
# Processing Record 44 of Set 11 | nuuk
# Processing Record 45 of Set 11 | kupang
# Processing Record 46 of Set 11 | sedelnikovo
# City not found. Skipping...
# Processing Record 47 of Set 11 | luderitz
# Processing Record 48 of Set 11 | elizabethtown
# Processing Record 49 of Set 11 | andros town
# Processing Record 50 of Set 11 | roald
# Processing Record 1 of Set 12 | hammelburg
# Processing Record 2 of Set 12 | tweed
# Processing Record 3 of Set 12 | scarborough
# Processing Record 4 of Set 12 | mezen
# Processing Record 5 of Set 12 | tiznit
# Processing Record 6 of Set 12 | shalinskoye
# Processing Record 7 of Set 12 | pudozh
# Processing Record 8 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 12 | benidorm
# Processing Record 10 of Set 12 | bara
# Processing Record 11 of Set 12 | plettenberg bay
# Processing Record 12 of Set 12 | turan
# Processing Record 13 of Set 12 | smithers
# Processing Record 14 of Set 12 | devgarh
# Processing Record 15 of Set 12 | bereda
# Processing Record 16 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 17 of Set 12 | labrea
# Processing Record 18 of Set 12 | laguna
# Processing Record 19 of Set 12 | roebourne
# Processing Record 20 of Set 12 | boyabat
# Processing Record 21 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 22 of Set 12 | barreirinhas
# Processing Record 23 of Set 12 | verkhnyaya maksakovka
# Processing Record 24 of Set 12 | yerbogachen
# Processing Record 25 of Set 12 | sobolevo
# Processing Record 26 of Set 12 | kavaratti
# Processing Record 27 of Set 12 | zeya
# Processing Record 28 of Set 12 | northam
# Processing Record 29 of Set 12 | calvinia
# Processing Record 30 of Set 12 | pacifica
# Processing Record 31 of Set 12 | yar-sale
# Processing Record 32 of Set 12 | rorvik
# Processing Record 33 of Set 12 | pangai
# Processing Record 34 of Set 12 | neuquen
# Processing Record 35 of Set 12 | marabba
# Processing Record 36 of Set 12 | ures
# Processing Record 37 of Set 12 | senanga
# Processing Record 38 of Set 12 | raga
# Processing Record 39 of Set 12 | bilibino
# Processing Record 40 of Set 12 | ferreira do alentejo
# Processing Record 41 of Set 12 | arenillas
# Processing Record 42 of Set 12 | puerto berrio
# Processing Record 43 of Set 12 | mandalgovi
# Processing Record 44 of Set 12 | moi
# Processing Record 45 of Set 12 | manicore
# Processing Record 46 of Set 12 | keti bandar
# Processing Record 47 of Set 12 | alta floresta
# Processing Record 48 of Set 12 | vetlanda
# Processing Record 49 of Set 12 | mvomero
# Processing Record 50 of Set 12 | san jeronimo
# Processing Record 1 of Set 13 | gulshat
# City not found. Skipping...
# Processing Record 2 of Set 13 | mahajanga
# Processing Record 3 of Set 13 | whyalla
# Processing Record 4 of Set 13 | tir pol
# City not found. Skipping...
# Processing Record 5 of Set 13 | salta
# Processing Record 6 of Set 13 | rupea
# Processing Record 7 of Set 13 | high rock
# Processing Record 8 of Set 13 | vorta
# Processing Record 9 of Set 13 | umba
# Processing Record 10 of Set 13 | banjar
# Processing Record 11 of Set 13 | road town
# Processing Record 12 of Set 13 | colac
# Processing Record 13 of Set 13 | yulara
# Processing Record 14 of Set 13 | bathsheba
# Processing Record 15 of Set 13 | port-cartier
# Processing Record 16 of Set 13 | itoman
# Processing Record 17 of Set 13 | saint-francois
# Processing Record 18 of Set 13 | russellville
# Processing Record 19 of Set 13 | matamoros
# Processing Record 20 of Set 13 | osinki
# Processing Record 21 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 22 of Set 13 | la palma
# Processing Record 23 of Set 13 | chupaca
# Processing Record 24 of Set 13 | hofn
# Processing Record 25 of Set 13 | valparaiso
# Processing Record 26 of Set 13 | jiayuguan
# Processing Record 27 of Set 13 | cockburn town
# Processing Record 28 of Set 13 | ust-ilimsk
# Processing Record 29 of Set 13 | borogontsy
# Processing Record 30 of Set 13 | dhing
# Processing Record 31 of Set 13 | champerico
# Processing Record 32 of Set 13 | yarmouth
# Processing Record 33 of Set 13 | kenitra
# Processing Record 34 of Set 13 | petatlan
# Processing Record 35 of Set 13 | linxia
# Processing Record 36 of Set 13 | tabialan
# City not found. Skipping...
# Processing Record 37 of Set 13 | zmeinogorsk
# Processing Record 38 of Set 13 | west des moines
# Processing Record 39 of Set 13 | kysyl-syr
# Processing Record 40 of Set 13 | monte alegre
# Processing Record 41 of Set 13 | launceston
# Processing Record 42 of Set 13 | centralia
# Processing Record 43 of Set 13 | fort nelson
# Processing Record 44 of Set 13 | lagoa
# Processing Record 45 of Set 13 | play cu
# City not found. Skipping...
# Processing Record 46 of Set 13 | raozan
# City not found. Skipping...
# Processing Record 47 of Set 13 | rezekne
# Processing Record 48 of Set 13 | qiongshan
# Processing Record 49 of Set 13 | itagi
# Processing Record 50 of Set 13 | port keats
# Processing Record 1 of Set 14 | gubkinskiy
# Processing Record 2 of Set 14 | cururupu
# Processing Record 3 of Set 14 | dien bien
# City not found. Skipping...
# Processing Record 4 of Set 14 | mattru
# Processing Record 5 of Set 14 | dalvik
# Processing Record 6 of Set 14 | luau
# Processing Record 7 of Set 14 | araouane
# Processing Record 8 of Set 14 | fukue
# Processing Record 9 of Set 14 | vostok
# Processing Record 10 of Set 14 | dordrecht
# Processing Record 11 of Set 14 | nunkini
# Processing Record 12 of Set 14 | nyurba
# Processing Record 13 of Set 14 | lalibela
# Processing Record 14 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 14 | blacklick estates
# Processing Record 16 of Set 14 | jefferson city
# Processing Record 17 of Set 14 | severo-yeniseyskiy
# Processing Record 18 of Set 14 | kasongo-lunda
# Processing Record 19 of Set 14 | bosaso
# Processing Record 20 of Set 14 | sorong
# Processing Record 21 of Set 14 | christchurch
# Processing Record 22 of Set 14 | nagorsk
# Processing Record 23 of Set 14 | quang ngai
# Processing Record 24 of Set 14 | oranjemund
# Processing Record 25 of Set 14 | port-gentil
# Processing Record 26 of Set 14 | kachiry
# Processing Record 27 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 28 of Set 14 | ribeira brava
# Processing Record 29 of Set 14 | pangody
# Processing Record 30 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 14 | ocos
# Processing Record 32 of Set 14 | tungor
# Processing Record 33 of Set 14 | longonjo
# Processing Record 34 of Set 14 | pokosnoye
# Processing Record 35 of Set 14 | walvis bay
# Processing Record 36 of Set 14 | belyy yar
# Processing Record 37 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 38 of Set 14 | aklavik
# Processing Record 39 of Set 14 | redmond
# Processing Record 40 of Set 14 | atherton
# Processing Record 41 of Set 14 | bambari
# Processing Record 42 of Set 14 | denpasar
# Processing Record 43 of Set 14 | farmington
# Processing Record 44 of Set 14 | la paz
# Processing Record 45 of Set 14 | noyakert
# Processing Record 46 of Set 14 | shakiso
# Processing Record 47 of Set 14 | pueblo
# Processing Record 48 of Set 14 | barcelona
# Processing Record 49 of Set 14 | hami
# Processing Record 50 of Set 14 | basoko
# Processing Record 1 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 15 | dawlatabad
# Processing Record 3 of Set 15 | taywarah
# Processing Record 4 of Set 15 | evensk
# Processing Record 5 of Set 15 | katobu
# Processing Record 6 of Set 15 | pontivy
# Processing Record 7 of Set 15 | guapo
# Processing Record 8 of Set 15 | nova soure
# Processing Record 9 of Set 15 | brae
# Processing Record 10 of Set 15 | baruun-urt
# Processing Record 11 of Set 15 | punta cardon
# Processing Record 12 of Set 15 | half moon bay
# Processing Record 13 of Set 15 | utete
# Processing Record 14 of Set 15 | seoul
# Processing Record 15 of Set 15 | katherine
# Processing Record 16 of Set 15 | hanzhong
# Processing Record 17 of Set 15 | ban nahin
# Processing Record 18 of Set 15 | stamsund
# City not found. Skipping...
# Processing Record 19 of Set 15 | nha trang
# Processing Record 20 of Set 15 | kingaroy
# Processing Record 21 of Set 15 | guiyang
# Processing Record 22 of Set 15 | santa isabel
# Processing Record 23 of Set 15 | kudahuvadhoo
# Processing Record 24 of Set 15 | mouila
# Processing Record 25 of Set 15 | bagn
# Processing Record 26 of Set 15 | pangnirtung
# Processing Record 27 of Set 15 | puerto escondido
# Processing Record 28 of Set 15 | moncton
# Processing Record 29 of Set 15 | chillicothe
# Processing Record 30 of Set 15 | mumford
# Processing Record 31 of Set 15 | codajas
# Processing Record 32 of Set 15 | zhezkazgan
# Processing Record 33 of Set 15 | kiruna
# Processing Record 34 of Set 15 | mana
# Processing Record 35 of Set 15 | kindu
# Processing Record 36 of Set 15 | riverton
# Processing Record 37 of Set 15 | bahia blanca
# Processing Record 38 of Set 15 | pilar
# Processing Record 39 of Set 15 | verkhne-katunskoye
# City not found. Skipping...
# Processing Record 40 of Set 15 | flin flon
# Processing Record 41 of Set 15 | abilene
# Processing Record 42 of Set 15 | awjilah
# Processing Record 43 of Set 15 | nome
# Processing Record 44 of Set 15 | noumea
# Processing Record 45 of Set 15 | dongsheng
# Processing Record 46 of Set 15 | yaan
# Processing Record 47 of Set 15 | la ronge
# Processing Record 48 of Set 15 | mangan
# Processing Record 49 of Set 15 | lerwick
# Processing Record 50 of Set 15 | maceio
# Processing Record 1 of Set 16 | coracao de jesus
# Processing Record 2 of Set 16 | pirgos
# Processing Record 3 of Set 16 | chumikan
# Processing Record 4 of Set 16 | marawi
# Processing Record 5 of Set 16 | matay
# Processing Record 6 of Set 16 | morondava
# Processing Record 7 of Set 16 | tahoua
# Processing Record 8 of Set 16 | sao desiderio
# Processing Record 9 of Set 16 | santiago de cuba
# Processing Record 10 of Set 16 | middle island
# Processing Record 11 of Set 16 | charters towers
# Processing Record 12 of Set 16 | gondar
# Processing Record 13 of Set 16 | bac lieu
# Processing Record 14 of Set 16 | buraydah
# Processing Record 15 of Set 16 | high level
# Processing Record 16 of Set 16 | oga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create the DataFrame
city_data_df = pd.DataFrame(city_data)

# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the city_data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
